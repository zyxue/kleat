# %%
tcga_path = '/projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2169027.02d9d59b-de6f-41c7-b529-142116debfd9.130529_UNC9-SN296_0368_AD24URACXX_8_TTAGGC.tar.gz'
c2g_bam_file = f'{tcga_path}/tasrkleat-results/align_contigs2genome/cba.sorted.bam'
r2c_bam_file = f'{tcga_path}/tasrkleat-results/align_reads2contigs/cba.sorted.bam'

# %%
# run ../benchmark_scripts/visualize-alignments.py -c {c2g_bam_file} -r {r2c_bam_file} -t A1.J70460 -s chr12 -l 25357659

# %%
run ../benchmark_scripts/visualize-alignments.py -c /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2169027.02d9d59b-de6f-41c7-b529-142116debfd9.130529_UNC9-SN296_0368_AD24URACXX_8_TTAGGC.tar.gz/tasrkleat-results/align_contigs2genome/cba.sorted.bam -r /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2169027.02d9d59b-de6f-41c7-b529-142116debfd9.130529_UNC9-SN296_0368_AD24URACXX_8_TTAGGC.tar.gz/tasrkleat-results/align_reads2contigs/cba.sorted.bam -t A1.J70460 -s chr12 -l 25357659 --seqname-beg-end 25357000 25358100
# Out:
# 2018-07-26 12:25:23,989|INFO|c2g_bam_file: /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2169027.02d9d59b-de6f-41c7-b529-142116debfd9.130529_UNC9-SN296_0368_AD24URACXX_8_TTAGGC.tar.gz/tasrkleat-results/align_contigs2genome/cba.sorted.bam
# 2018-07-26 12:25:23,990|INFO|r2g_bam_file: /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2169027.02d9d59b-de6f-41c7-b529-142116debfd9.130529_UNC9-SN296_0368_AD24URACXX_8_TTAGGC.tar.gz/tasrkleat-results/align_reads2contigs/cba.sorted.bam
# 35513it [00:00, 354998.30it/s]
# 2018-07-26 12:25:24,260|INFO|contig.query_name: A1.J70460
# 2018-07-26 12:25:24,261|INFO|contig.is_reverse: False
# 2018-07-26 12:25:24,262|INFO|contig.cigarstring: 486M2D52M1D364M
# 2018-07-26 12:25:24,263|INFO|contig.reference_start: 25357088
# 2018-07-26 12:25:24,264|INFO|contig.reference_end: 25357993
# ...

# %%
run ../benchmark_scripts/visualize-alignments.py -c /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2170205.3858b3ae-a4a9-4b91-8bd3-b7e20fb531e4.130517_UNC9-SN296_0366_BD250HACXX_1_ATCACG.tar.gz/tasrkleat-results/align_contigs2genome/cba.sorted.bam -r /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2170205.3858b3ae-a4a9-4b91-8bd3-b7e20fb531e4.130517_UNC9-SN296_0366_BD250HACXX_1_ATCACG.tar.gz/tasrkleat-results/align_reads2contigs/cba.sorted.bam -t A1.S33037 -s chr12 -l 25357659  --seqname-beg-end 25357000 25358100
# Out:
# 2018-07-20 11:44:26,344|INFO|c2g_bam_file: /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2170205.3858b3ae-a4a9-4b91-8bd3-b7e20fb531e4.130517_UNC9-SN296_0366_BD250HACXX_1_ATCACG.tar.gz/tasrkleat-results/align_contigs2genome/cba.sorted.bam
# 2018-07-20 11:44:26,346|INFO|r2g_bam_file: /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2170205.3858b3ae-a4a9-4b91-8bd3-b7e20fb531e4.130517_UNC9-SN296_0366_BD250HACXX_1_ATCACG.tar.gz/tasrkleat-results/align_reads2contigs/cba.sorted.bam
# 32967it [00:00, 329262.10it/s]
# 2018-07-20 11:44:26,471|INFO|contig.query_name: A1.S33037
# 2018-07-20 11:44:26,472|INFO|contig.is_reverse: False
# 2018-07-20 11:44:26,473|INFO|contig.cigarstring: 249M2D373M8S
# 2018-07-20 11:44:26,474|INFO|contig.reference_start: 25357325
# 2018-07-20 11:44:26,475|INFO|contig.reference_end: 25357949

# %%
run ../benchmark_scripts/visualize-alignments.py -c /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2206547.6b52803e-274b-4a1b-910f-2d307932bbb2.110926_UNC12-SN629_0143_AD0DY7ABXX_6_CTTGTA.tar.gz/tasrkleat-results/align_contigs2genome/cba.sorted.bam -r /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2206547.6b52803e-274b-4a1b-910f-2d307932bbb2.110926_UNC12-SN629_0143_AD0DY7ABXX_6_CTTGTA.tar.gz/tasrkleat-results/align_reads2contigs/cba.sorted.bam -t A1.S67496 -s chr12 -l 25357659 --seqname-beg-end 25357000 25358100
# Out:
# 2018-07-20 11:44:27,725|INFO|c2g_bam_file: /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2206547.6b52803e-274b-4a1b-910f-2d307932bbb2.110926_UNC12-SN629_0143_AD0DY7ABXX_6_CTTGTA.tar.gz/tasrkleat-results/align_contigs2genome/cba.sorted.bam
# 2018-07-20 11:44:27,726|INFO|r2g_bam_file: /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2206547.6b52803e-274b-4a1b-910f-2d307932bbb2.110926_UNC12-SN629_0143_AD0DY7ABXX_6_CTTGTA.tar.gz/tasrkleat-results/align_reads2contigs/cba.sorted.bam
# 38914it [00:00, 388973.44it/s]
# 2018-07-20 11:44:27,933|INFO|contig.query_name: A1.S67496
# 2018-07-20 11:44:27,934|INFO|contig.is_reverse: False
# 2018-07-20 11:44:27,935|INFO|contig.cigarstring: 939M
# 2018-07-20 11:44:27,936|INFO|contig.reference_start: 25357110
# 2018-07-20 11:44:27,937|INFO|contig.reference_end: 25358049

# %%
run ../benchmark_scripts/visualize-alignments.py -c /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2189444.7C521EF7-4ADF-46EF-ADE0-088CBE02223D.120529_UNC16-SN851_0164_AD12VAACXX_4_ATCACG.tar.gz/tasrkleat-results/align_contigs2genome/cba.sorted.bam -r /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2189444.7C521EF7-4ADF-46EF-ADE0-088CBE02223D.120529_UNC16-SN851_0164_AD12VAACXX_4_ATCACG.tar.gz/tasrkleat-results/align_reads2contigs/cba.sorted.bam -t A0.R359536 -s chr12 -l 25357659  --seqname-beg-end 25357000 25358100
# Out:
# 2018-07-20 11:44:29,014|INFO|c2g_bam_file: /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2189444.7C521EF7-4ADF-46EF-ADE0-088CBE02223D.120529_UNC16-SN851_0164_AD12VAACXX_4_ATCACG.tar.gz/tasrkleat-results/align_contigs2genome/cba.sorted.bam
# 2018-07-20 11:44:29,015|INFO|r2g_bam_file: /projects/btl/zxue/tasrkleat-TCGA-results/tcga/BRCA/RNA/RNA-Seq/UNC-LCCC/ILLUMINA/UNCID_2189444.7C521EF7-4ADF-46EF-ADE0-088CBE02223D.120529_UNC16-SN851_0164_AD12VAACXX_4_ATCACG.tar.gz/tasrkleat-results/align_reads2contigs/cba.sorted.bam
# 147023it [00:00, 489889.09it/s]
# 2018-07-20 11:44:29,370|INFO|contig.query_name: A0.R359536
# 2018-07-20 11:44:29,372|INFO|contig.is_reverse: True
# 2018-07-20 11:44:29,373|INFO|contig.cigarstring: 3S903M
# 2018-07-20 11:44:29,374|INFO|contig.reference_start: 25357134
# 2018-07-20 11:44:29,375|INFO|contig.reference_end: 25358037
