# %%
from eda_imports import *
from adjustText import adjust_text

# %%
adf = pd.read_pickle('../benchmark_transcriptome/tcga-run-4/UHRC1.pkl')

# %%
adf.shape
# Out:
# (870121, 31)

# %%
bdf = adf.query('contig_max_len > 150').query('ref_hex != "NA"')

# %%
bdf.shape
# Out:
# (66214, 31)

# %%
mismatch_df = bdf.query('ref_hex != ctg_hex')

# %%
mismatch_df.shape
# Out:
# (3202, 31)

# %%
mismatch_df.shape[0] / bdf.shape[0]
# Out:
# 0.048358353218352614

# %%
adf2 = pd.read_pickle('../benchmark_transcriptome/ctg-hex-comparison/UHRC1.pkl')

# %%
adf2.shape
# Out:
# (870121, 31)

# %%
bdf2 = adf2.query('contig_max_len > 150').query('ref_hex != "NA"')

# %%
bdf2.shape
# Out:
# (66214, 31)

# %%
mismatch_df2 = bdf2.query('ref_hex != ctg_hex')

# %%
mismatch_df2.shape
# Out:
# (4167, 31)

# %%
mismatch_df2.shape[0] / bdf2.shape[0]
# Out:
# 0.06293231038753133

# %%
# cols = ['seqname', 'strand', 'clv', 'ctg_hex', 'ctg_hex_id', 'ctg_hex_pos', 'ctg_hex_dist', 'ref_hex', 'ref_hex_id', 'ref_hex_pos', 'ref_hex_dist', 'signed_dist_to_aclv', 'evidence_type', 'contig_ids_at_pos', 'any_contig_is_hardclipped', 'contig_max_len', 'aclv', 'gene_name', 'gene_id', 'contig_max_mapq', 'num_contigs_suffix', 'num_contigs_bridge', 'num_contigs_link', 'num_contigs_blank', 'num_total_contigs',
#        'num_reads_suffix', 'num_reads_bridge', 'num_reads_link', 'max_read_tail_len_suffix', 'max_read_tail_len_bridge', 'max_contig_tail_len_suffix']

# %%
# mismatch_df2.sort_values('contig_max_len', ascending=False).head()[cols]

# %%
diff_df = mismatch_df2.query(f'clv not in {mismatch_df.clv.values.tolist()}')

# %%
diff_df.sort_values('contig_max_len', ascending=False).head(30)
# Out:
#        seqname strand        clv       aclv      gene_name          gene_id  signed_dist_to_aclv evidence_type          contig_ids_at_pos any_contig_is_hardclipped contig_max_len contig_max_mapq num_contigs_suffix num_contigs_bridge num_contigs_link num_contigs_blank num_total_contigs  \
# 793078  chr8    -      100514064  100548863  MIR599         ENSG00000207804 -34799                blank         E1.L.9554@0                False                     8679           40              0                  0                  0                1                 1
# 465475  chr2    -      96948938   96950552   SNRNP200       ENSG00000144028 -1614                 bridge        E2.L.558@2183              False                     7212           40              0                  1                  0                0                 1
# 861999  chrX    -      76855036   76855203   ATRX           ENSG00000085224 -167                  bridge        E1.L.3046@1810             False                     7205           40              0                  1                  0                0                 1
# 811972  chr9    +      128069695  128071579  GAPVD1         ENSG00000165219 -1884                 bridge        E1.L.3659@1211             False                     6744           40              0                  1                  0                0                 1
# 256250  chr15   +      29992962   29973162   RP11-680F8.1   ENSG00000256802  19800                bridge        01.L.368526@45             False                     6319           40              0                  1                  0                0                 1
# 707090  chr6    -      82900928   82901047   IBTK           ENSG00000005700 -119                  bridge        E1.L.3982@1826             False                     5818           40              0                  1                  0                0                 1
# 326923  chr17   +      38556474   38530429   RNA5SP441      ENSG00000252618  26045                bridge        E2.L.249@2609              False                     5730           40              0                  1                  0                0                 1
diff_df.query('ref_hex_pos == 128159684')
# Out:
#        seqname strand        clv       aclv gene_name          gene_id  signed_dist_to_aclv evidence_type contig_ids_at_pos any_contig_is_hardclipped contig_max_len contig_max_mapq num_contigs_suffix num_contigs_bridge num_contigs_link num_contigs_blank num_total_contigs num_reads_suffix  \
# 736032  chr7    +      128159699  128146656  METTL2B   ENSG00000165055  13043                bridge        E2.L.2812@322     False                     480            40              0                  1                  0                0                 1                 0
#
#        num_reads_bridge num_reads_link max_read_tail_len_suffix max_read_tail_len_bridge max_contig_tail_len_suffix ctg_hex ctg_hex_id ctg_hex_pos ctg_hex_dist ref_hex ref_hex_id ref_hex_pos ref_hex_dist
# 736032  1                0              0                        5                        0                          AATACA  9          128159688   11           AATAAA  16         128159684   15

# %%
diff_df.query('ref_hex_pos == 132424866')
# Out:
#        seqname strand        clv       aclv     gene_name          gene_id  signed_dist_to_aclv evidence_type contig_ids_at_pos any_contig_is_hardclipped contig_max_len contig_max_mapq num_contigs_suffix num_contigs_bridge num_contigs_link num_contigs_blank num_total_contigs num_reads_suffix  \
# 663684  chr5    -      132424829  132446746  RP11-485M7.3  ENSG00000251616 -21917                blank         E1.S.22410@0      False                     2980           40              0                  0                  0                1                 1                 0
#
#        num_reads_bridge num_reads_link max_read_tail_len_suffix max_read_tail_len_bridge max_contig_tail_len_suffix ctg_hex ctg_hex_id ctg_hex_pos ctg_hex_dist ref_hex ref_hex_id ref_hex_pos ref_hex_dist
# 663684  0                0              0                        0                        0                          NA      -1         -1          -1           AATAAA  16         132424866   37

# %%
adf.query('ref_hex_pos == 132424866')
# Out:
#        seqname strand        clv       aclv     gene_name          gene_id  signed_dist_to_aclv evidence_type contig_ids_at_pos any_contig_is_hardclipped contig_max_len contig_max_mapq num_contigs_suffix num_contigs_bridge num_contigs_link num_contigs_blank num_total_contigs num_reads_suffix  \
# 663684  chr5    -      132424829  132446746  RP11-485M7.3  ENSG00000251616 -21917                blank         E1.S.22410@0      False                     2980           40              0                  0                  0                1                 1                 0
#
#        num_reads_bridge num_reads_link max_read_tail_len_suffix max_read_tail_len_bridge max_contig_tail_len_suffix ctg_hex ctg_hex_id ctg_hex_pos ctg_hex_dist ref_hex ref_hex_id ref_hex_pos ref_hex_dist
# 663684  0                0              0                        0                        0                          AATAAA  16         132424866   37           AATAAA  16         132424866   37

# %%
adf2.query('ref_hex_pos == 132424866')
# Out:
#        seqname strand        clv       aclv     gene_name          gene_id  signed_dist_to_aclv evidence_type contig_ids_at_pos any_contig_is_hardclipped contig_max_len contig_max_mapq num_contigs_suffix num_contigs_bridge num_contigs_link num_contigs_blank num_total_contigs num_reads_suffix  \
# 663684  chr5    -      132424829  132446746  RP11-485M7.3  ENSG00000251616 -21917                blank         E1.S.22410@0      False                     2980           40              0                  0                  0                1                 1                 0
#
#        num_reads_bridge num_reads_link max_read_tail_len_suffix max_read_tail_len_bridge max_contig_tail_len_suffix ctg_hex ctg_hex_id ctg_hex_pos ctg_hex_dist ref_hex ref_hex_id ref_hex_pos ref_hex_dist
# 663684  0                0              0                        0                        0                          NA      -1         -1          -1           AATAAA  16         132424866   37

# %%
diff_df.shape
# Out:
# (109, 31)

# %%
# diff_df.sort_values('contig_max_len', ascending=False).head(50)
